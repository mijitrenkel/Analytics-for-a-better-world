# %% [markdown]
# ABW Assignment 1: Feed Calculator

# %%
import sys
at_colab = "google.colab" in sys.modules
if at_colab:
    import shutil
    if not shutil.which("pyomo"):
        # !pip install -q pyomo
        assert(shutil.which("pyomo"))
if at_colab:
    if not shutil.which('/usr/bin/glpsol'):
        # !sudo apt install libglpk-dev python3.8-dev libgmp3-dev
        # !apt-get install -y -qq glpk-utils
        assert(shutil.which('/usr/bin/glpsol'))

    if not shutil.which('/usr/bin/cbc'):
        # !apt-get install -y -qq coinor-cbc
        assert(shutil.which('/usr/bin/cbc'))

import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd
import pyomo.environ as pyo

import sys
if 'google.colab' in sys.modules:
    import os
    from google.colab import files
    # just check if we already uploaded, may we restart the runtime and run all cells
    if not os.path.isfile('Data Set Feedcalculator.xlsx'):
        uploaded = files.upload()

#import and read data file 
data = pd.read_excel('Data Set Feedcalculator.xlsx',sheet_name=None)

#create data frames of data in excel
ingredients      = data['Ingredient Database']
nutrient_rules   = data['Nutrient Rules']
ingredient_rules = data['Ingredient Rules']

#create dataframe with all available nutrients
available_ingredients = ingredients[ingredients.Availability][['Name','Reference name','Price']+list(nutrient_rules.Nutrient)].set_index('Reference name')

#create a dictionary with keys: name of the nutrient and values: lower and upper bound of the nutrient
nutrient_bounds = { nut : (lb if not pd.isna(lb) else 0,     # no lower bound translates into 0 as lower bound
                           ub if not pd.isna(ub) else None)  # no upper bound becomes None
                    for nut,lb,ub in zip(nutrient_rules.Nutrient,nutrient_rules['Lower Bound'],nutrient_rules['Upper Bound']) 
                  }

ingredient_bounds = { ing : (lb if not pd.isna(lb) else 0,    # no lower bound translates into 0 as lower bound
                             ub if not pd.isna(ub) else None) # no upper bound becomes None
                      for ing,lb,ub in zip(ingredient_rules.Ingredient,ingredient_rules['Lower Bound'],ingredient_rules['Upper Bound']) }


combined_ingredient_rules   = [] 
set_of_availabe_ingredients = set(available_ingredients.index)
for c in ['Unnamed: '+str(i) for i in range(5,13)]:
    aux = ingredient_rules[[c]].dropna().values
    aux = [ v[0] for v in aux ]
    upperbound          = aux[0]
    ingredients_in_rule = set(aux[1:]).intersection(set_of_availabe_ingredients)
    if ingredients_in_rule:
        combined_ingredient_rules.append((upperbound,ingredients_in_rule))
combined_ingredient_rules

def FeedCalculator(available_ingredients, ingredient_bounds, combinded_ingredient_rules):

  model = pyo.ConcreteModel('FeedCalculator')

  model.ingredients = pyo.Set(initialize=available_ingredients.index)
  model.nutrients = pyo.Set(initialize=nutrient_bounds.keys())
  model.cir = pyo.Set(initialize = list(range(len(combined_ingredient_rules))))

  def bounds_rule(model, i):
    return ingredient_bounds.get(i, (0,None))
  
  model.x = pyo.Var(model.ingredients, bounds=bounds_rule, within = pyo.NonNegativeReals)

  model.optimal = pyo.Objective(expr = pyo.quicksum(available_ingredients.Price[i]*model.x[i] for i in model.ingredients), sense = pyo.minimize)

  #add constraint 1: weight of food has to qual one
  model.weight = pyo.Constraint(expr = pyo.quicksum(model.x[i] for i in model.ingredients) == 1)

  #add constraint 2: nutritional requirements have to be fulfilled
  def nutrient_rule(model, n):
    l, u= nutrient_bounds.get(n, (0, None))
    return (l, pyo.quicksum(model.x[i]*available_ingredients.loc[i][n] for i in model.ingredients), u)
  model.nutrition = pyo.Constraint(model.nutrients, rule = nutrient_rule)
   

  def combined_rule(model, r):
    return (pyo.quicksum(model.x[i] for i in combined_ingredient_rules[r][1]) <= combined_ingredient_rules[r][0])
  model.combined = pyo.Constraint(model.cir, rule = combined_rule)

  return model

FeedCalculator = FeedCalculator(available_ingredients, ingredient_bounds, nutrient_bounds)
FeedCalculator.pprint()

# %time results=pyo.SolverFactory('cbc').solve(FeedCalculator)
print(results.solver.status, results.solver.termination_condition)
print(FeedCalculator.optimal.expr())

FeedCalculator.display()
# Out:
#      |████████████████████████████████| 9.1 MB 7.2 MB/s
#      |████████████████████████████████| 49 kB 3.4 MB/s
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libamd2 libbtf1 libcamd2 libccolamd2 libcholmod3 libcolamd2 libcxsparse3
#   libglpk40 libgmp-dev libgmpxx4ldbl libgraphblas1 libklu1 libldl2 libmetis5
#   libpython3.8 libpython3.8-dev libpython3.8-minimal libpython3.8-stdlib
#   librbio2 libspqr2 libsuitesparse-dev libsuitesparseconfig5 libumfpack5
#   python3.8 python3.8-minimal
# Suggested packages:
#   libiodbc2-dev gmp-doc libgmp10-doc libmpfr-dev python3.8-venv python3.8-doc
#   binfmt-support
# The following NEW packages will be installed:
#   libamd2 libbtf1 libcamd2 libccolamd2 libcholmod3 libcolamd2 libcxsparse3
#   libglpk-dev libglpk40 libgmp-dev libgmp3-dev libgmpxx4ldbl libgraphblas1
#   libklu1 libldl2 libmetis5 libpython3.8 libpython3.8-dev libpython3.8-minimal
#   libpython3.8-stdlib librbio2 libspqr2 libsuitesparse-dev
#   libsuitesparseconfig5 libumfpack5 python3.8 python3.8-dev python3.8-minimal
# 0 upgraded, 28 newly installed, 0 to remove and 37 not upgraded.
# Need to get 15.0 MB of archives.
# After this operation, 69.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsuitesparseconfig5 amd64 1:5.1.2-2 [9,044 B]
# Get:2 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.8-minimal amd64 3.8.12-1+bionic1 [762 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libamd2 amd64 1:5.1.2-2 [19.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libbtf1 amd64 1:5.1.2-2 [10.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcamd2 amd64 1:5.1.2-2 [20.9 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libccolamd2 amd64 1:5.1.2-2 [21.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcolamd2 amd64 1:5.1.2-2 [16.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmetis5 amd64 5.1.0.dfsg-5 [169 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcholmod3 amd64 1:5.1.2-2 [300 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcxsparse3 amd64 1:5.1.2-2 [63.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglpk40 amd64 4.65-1 [378 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmpxx4ldbl amd64 2:6.1.2+dfsg-2 [8,964 B]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmp-dev amd64 2:6.1.2+dfsg-2 [316 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgraphblas1 amd64 1:5.1.2-2 [384 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libklu1 amd64 1:5.1.2-2 [69.3 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libldl2 amd64 1:5.1.2-2 [10.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libumfpack5 amd64 1:5.1.2-2 [229 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 librbio2 amd64 1:5.1.2-2 [24.0 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libspqr2 amd64 1:5.1.2-2 [64.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsuitesparse-dev amd64 1:5.1.2-2 [1,235 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglpk-dev amd64 4.65-1 [445 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmp3-dev amd64 2:6.1.2+dfsg-2 [1,996 B]
# Get:23 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 python3.8-minimal amd64 3.8.12-1+bionic1 [1,823 kB]
# Get:24 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.8-stdlib amd64 3.8.12-1+bionic1 [1,657 kB]
# Get:25 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.8 amd64 3.8.12-1+bionic1 [1,827 kB]
# Get:26 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.8-dev amd64 3.8.12-1+bionic1 [4,215 kB]
# Get:27 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 python3.8 amd64 3.8.12-1+bionic1 [433 kB]
# Get:28 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 python3.8-dev amd64 3.8.12-1+bionic1 [501 kB]
# Fetched 15.0 MB in 10s (1,466 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 28.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpython3.8-minimal:amd64.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../00-libpython3.8-minimal_3.8.12-1+bionic1_amd64.deb ...
# Unpacking libpython3.8-minimal:amd64 (3.8.12-1+bionic1) ...
# Selecting previously unselected package python3.8-minimal.
# Preparing to unpack .../01-python3.8-minimal_3.8.12-1+bionic1_amd64.deb ...
# Unpacking python3.8-minimal (3.8.12-1+bionic1) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../02-libsuitesparseconfig5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../03-libamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libbtf1:amd64.
# Preparing to unpack .../04-libbtf1_1%3a5.1.2-2_amd64.deb ...
# Unpacking libbtf1:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../05-libcamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../06-libccolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../07-libcolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../08-libmetis5_5.1.0.dfsg-5_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-5) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../09-libcholmod3_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcxsparse3:amd64.
# Preparing to unpack .../10-libcxsparse3_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcxsparse3:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libglpk40:amd64.
# Preparing to unpack .../11-libglpk40_4.65-1_amd64.deb ...
# Unpacking libglpk40:amd64 (4.65-1) ...
# Selecting previously unselected package libgmpxx4ldbl:amd64.
# Preparing to unpack .../12-libgmpxx4ldbl_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmpxx4ldbl:amd64 (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libgmp-dev:amd64.
# Preparing to unpack .../13-libgmp-dev_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmp-dev:amd64 (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libgraphblas1:amd64.
# Preparing to unpack .../14-libgraphblas1_1%3a5.1.2-2_amd64.deb ...
# Unpacking libgraphblas1:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libklu1:amd64.
# Preparing to unpack .../15-libklu1_1%3a5.1.2-2_amd64.deb ...
# Unpacking libklu1:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libldl2:amd64.
# Preparing to unpack .../16-libldl2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libldl2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libumfpack5:amd64.
# Preparing to unpack .../17-libumfpack5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libumfpack5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package librbio2:amd64.
# Preparing to unpack .../18-librbio2_1%3a5.1.2-2_amd64.deb ...
# Unpacking librbio2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libspqr2:amd64.
# Preparing to unpack .../19-libspqr2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libspqr2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libsuitesparse-dev:amd64.
# Preparing to unpack .../20-libsuitesparse-dev_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparse-dev:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libglpk-dev:amd64.
# Preparing to unpack .../21-libglpk-dev_4.65-1_amd64.deb ...
# Unpacking libglpk-dev:amd64 (4.65-1) ...
# Selecting previously unselected package libgmp3-dev.
# Preparing to unpack .../22-libgmp3-dev_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmp3-dev (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libpython3.8-stdlib:amd64.
# Preparing to unpack .../23-libpython3.8-stdlib_3.8.12-1+bionic1_amd64.deb ...
# Unpacking libpython3.8-stdlib:amd64 (3.8.12-1+bionic1) ...
# Selecting previously unselected package libpython3.8:amd64.
# Preparing to unpack .../24-libpython3.8_3.8.12-1+bionic1_amd64.deb ...
# Unpacking libpython3.8:amd64 (3.8.12-1+bionic1) ...
# Selecting previously unselected package libpython3.8-dev:amd64.
# Preparing to unpack .../25-libpython3.8-dev_3.8.12-1+bionic1_amd64.deb ...
# Unpacking libpython3.8-dev:amd64 (3.8.12-1+bionic1) ...
# Selecting previously unselected package python3.8.
# Preparing to unpack .../26-python3.8_3.8.12-1+bionic1_amd64.deb ...
# Unpacking python3.8 (3.8.12-1+bionic1) ...
# Selecting previously unselected package python3.8-dev.
# Preparing to unpack .../27-python3.8-dev_3.8.12-1+bionic1_amd64.deb ...
# Unpacking python3.8-dev (3.8.12-1+bionic1) ...
# Setting up libbtf1:amd64 (1:5.1.2-2) ...
# Setting up libldl2:amd64 (1:5.1.2-2) ...
# Setting up libcxsparse3:amd64 (1:5.1.2-2) ...
# Setting up libpython3.8-minimal:amd64 (3.8.12-1+bionic1) ...
# Setting up libgraphblas1:amd64 (1:5.1.2-2) ...
# Setting up python3.8-minimal (3.8.12-1+bionic1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-5) ...
# Setting up libcolamd2:amd64 (1:5.1.2-2) ...
# Setting up libccolamd2:amd64 (1:5.1.2-2) ...
# Setting up libgmpxx4ldbl:amd64 (2:6.1.2+dfsg-2) ...
# Setting up libpython3.8-stdlib:amd64 (3.8.12-1+bionic1) ...
# Setting up libpython3.8:amd64 (3.8.12-1+bionic1) ...
# Setting up libgmp-dev:amd64 (2:6.1.2+dfsg-2) ...
# Setting up libpython3.8-dev:amd64 (3.8.12-1+bionic1) ...
# Setting up python3.8 (3.8.12-1+bionic1) ...
# Setting up librbio2:amd64 (1:5.1.2-2) ...
# Setting up libcamd2:amd64 (1:5.1.2-2) ...
# Setting up python3.8-dev (3.8.12-1+bionic1) ...
# Setting up libamd2:amd64 (1:5.1.2-2) ...
# Setting up libgmp3-dev (2:6.1.2+dfsg-2) ...
# Setting up libglpk40:amd64 (4.65-1) ...
# Setting up libklu1:amd64 (1:5.1.2-2) ...
# Setting up libcholmod3:amd64 (1:5.1.2-2) ...
# Setting up libspqr2:amd64 (1:5.1.2-2) ...
# Setting up libumfpack5:amd64 (1:5.1.2-2) ...
# Setting up libsuitesparse-dev:amd64 (1:5.1.2-2) ...
# Setting up libglpk-dev:amd64 (4.65-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Selecting previously unselected package glpk-utils.
# (Reading database ... 156063 files and directories currently installed.)
# Preparing to unpack .../glpk-utils_4.65-1_amd64.deb ...
# Unpacking glpk-utils (4.65-1) ...
# Setting up glpk-utils (4.65-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Selecting previously unselected package coinor-libcoinutils3v5.
# (Reading database ... 156241 files and directories currently installed.)
# Preparing to unpack .../0-coinor-libcoinutils3v5_2.10.14+repack1-1_amd64.deb ...
# Unpacking coinor-libcoinutils3v5 (2.10.14+repack1-1) ...
# Selecting previously unselected package coinor-libosi1v5.
# Preparing to unpack .../1-coinor-libosi1v5_0.107.9+repack1-1_amd64.deb ...
# Unpacking coinor-libosi1v5 (0.107.9+repack1-1) ...
# Selecting previously unselected package coinor-libclp1.
# Preparing to unpack .../2-coinor-libclp1_1.16.11+repack1-1_amd64.deb ...
# Unpacking coinor-libclp1 (1.16.11+repack1-1) ...
# Selecting previously unselected package coinor-libcgl1.
# Preparing to unpack .../3-coinor-libcgl1_0.59.10+repack1-1_amd64.deb ...
# Unpacking coinor-libcgl1 (0.59.10+repack1-1) ...
# Selecting previously unselected package coinor-libcbc3.
# Preparing to unpack .../4-coinor-libcbc3_2.9.9+repack1-1_amd64.deb ...
# Unpacking coinor-libcbc3 (2.9.9+repack1-1) ...
# Selecting previously unselected package coinor-cbc.
# Preparing to unpack .../5-coinor-cbc_2.9.9+repack1-1_amd64.deb ...
# Unpacking coinor-cbc (2.9.9+repack1-1) ...
# Setting up coinor-libcoinutils3v5 (2.10.14+repack1-1) ...
# Setting up coinor-libosi1v5 (0.107.9+repack1-1) ...
# Setting up coinor-libclp1 (1.16.11+repack1-1) ...
# Setting up coinor-libcgl1 (0.59.10+repack1-1) ...
# Setting up coinor-libcbc3 (2.9.9+repack1-1) ...
# Setting up coinor-cbc (2.9.9+repack1-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#      <input type="file" id="files-9bf2ff06-e341-4e51-9a02-aef1f7b6e726" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9bf2ff06-e341-4e51-9a02-aef1f7b6e726">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data Set Feedcalculator.xlsx to Data Set Feedcalculator.xlsx
# 3 Set Declarations
#     cir : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    7 : {0, 1, 2, 3, 4, 5, 6}
#     ingredients : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   26 : {'barley', 'blood', 'boneash', 'cotton', 'fish', 'fishlq', 'gnseeds', 'maize', 'maizebranhighq', 'maizebranlowq', 'mbmeal', 'sugars', 'soybeanexp', 'soybeanmeal', 'sunflower', 'sunflowerseeds', 'tapbran', 'caswhole', 'casfine', 'wheatbran', 'lysine', 'dl', 'ltryp', 'dicaph', 'shells', 'salt'}
#     nutrients : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   14 : {'oebr', 'cp', 'cfibre', 'staew', 'ca', 'na', 'opp', 'dlysp', 'dmetp', 'dmcp', 'dthrp', 'dtryp', 'dvalp', 'dargp'}
#
# 1 Var Declarations
#     x : Size=26, Index=ingredients
#         Key            : Lower : Value : Upper : Fixed : Stale : Domain
#                 barley :     0 :  None :   0.1 : False :  True : NonNegativeReals
#                  blood :     0 :  None :  0.03 : False :  True : NonNegativeReals
#                boneash :     0 :  None :  0.03 : False :  True : NonNegativeReals
#                casfine :     0 :  None :  0.25 : False :  True : NonNegativeReals
#               caswhole :     0 :  None :  0.25 : False :  True : NonNegativeReals
#                 cotton :     0 :  None :  0.06 : False :  True : NonNegativeReals
#                 dicaph :     0 :  None :  None : False :  True : NonNegativeReals
#                     dl :     0 :  None :  None : False :  True : NonNegativeReals
#                   fish :     0 :  None :  0.07 : False :  True : NonNegativeReals
#                 fishlq :     0 :  None :  0.07 : False :  True : NonNegativeReals
#                gnseeds :     0 :  None :   0.1 : False :  True : NonNegativeReals
#                  ltryp :     0 :  None :  None : False :  True : NonNegativeReals
#                 lysine :     0 :  None :  None : False :  True : NonNegativeReals
#                  maize :   0.2 :  None :  None : False :  True : NonNegativeReals
#         maizebranhighq :     0 :  None :  0.25 : False :  True : NonNegativeReals
#          maizebranlowq :     0 :  None :  0.15 : False :  True : NonNegativeReals
#                 mbmeal :     0 :  None :  0.05 : False :  True : NonNegativeReals
#                   salt :     0 :  None : 0.003 : False :  True : NonNegativeReals
#                 shells :     0 :  None :  None : False :  True : NonNegativeReals
#             soybeanexp :     0 :  None :  0.07 : False :  True : NonNegativeReals
#            soybeanmeal :     0 :  None :  0.32 : False :  True : NonNegativeReals
#                 sugars :     0 :  None :  0.01 : False :  True : NonNegativeReals
#              sunflower :     0 :  None :  0.12 : False :  True : NonNegativeReals
#         sunflowerseeds :     0 :  None :  0.12 : False :  True : NonNegativeReals
#                tapbran :     0 :  None :   0.2 : False :  True : NonNegativeReals
#              wheatbran :     0 :  None :  0.08 : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     optimal : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 0.26*x[barley] + 0.71*x[blood] + 0.18*x[boneash] + 0.2*x[cotton] + 0.63*x[fish] + 0.55*x[fishlq] + 0.59*x[gnseeds] + 0.33*x[maize] + 0.19*x[maizebranhighq] + 0.15*x[maizebranlowq] + 0.34*x[mbmeal] + 0.21*x[sugars] + 0.38*x[soybeanexp] + 0.38*x[soybeanmeal] + 0.2*x[sunflower] + 0.49*x[sunflowerseeds] + 0.23*x[tapbran] + 0.15*x[caswhole] + 0.18*x[casfine] + 0.18*x[wheatbran] + 2.5*x[lysine] + 6.25*x[dl] + 7.75*x[ltryp] + 0.88*x[dicaph] + 0.11*x[shells] + 0.25*x[salt]
#
# 3 Constraint Declarations
#     combined : Size=7, Index=cir, Active=True
#         Key : Lower : Body                                  : Upper : Active
#           0 :  -Inf :              x[cotton] + x[sunflower] :  0.17 :   True
#           1 :  -Inf :        x[soybeanexp] + x[soybeanmeal] :  0.35 :   True
#           2 :  -Inf :                             x[barley] :   0.3 :   True
#           3 :  -Inf :  x[maizebranhighq] + x[maizebranlowq] :  0.25 :   True
#           4 :  -Inf :                   x[fishlq] + x[fish] :  0.07 :   True
#           5 :  -Inf :                             x[mbmeal] :  0.08 :   True
#           6 :  -Inf : x[casfine] + x[caswhole] + x[tapbran] :  0.25 :   True
#     nutrition : Size=14, Index=nutrients, Active=True
#         Key    : Lower  : Body                                                                                                                                                                                                                                                                                                                                                                                                                                           : Upper  : Active
#             ca :    7.0 :                                   0.4*x[barley] + 0.5*x[blood] + 289.3*x[boneash] + 2.2*x[cotton] + 60.0*x[fish] + 141.0*x[fishlq] + x[gnseeds] + 0.1*x[maize] + 1.3*x[maizebranhighq] + 0.3*x[maizebranlowq] + 130.1*x[mbmeal] + 6.8*x[sugars] + 2.7*x[soybeanexp] + 3.1*x[soybeanmeal] + 3.0*x[sunflower] + 2.1*x[sunflowerseeds] + 2.5*x[tapbran] + 2.5*x[caswhole] + 2.5*x[casfine] + 0.9*x[wheatbran] + 240.0*x[dicaph] + 350.0*x[shells] :    9.0 :   True
#         cfibre :    0.0 :                                                                                                                      43.4*x[barley] + 10.0*x[blood] + 169.8*x[cotton] + 23.3*x[gnseeds] + 20.8*x[maize] + 39.6*x[maizebranhighq] + 98.6*x[maizebranlowq] + 15.1*x[mbmeal] + 60.4*x[soybeanexp] + 60.5*x[soybeanmeal] + 239.3*x[sunflower] + 176.0*x[sunflowerseeds] + 52.7*x[tapbran] + 86.0*x[caswhole] + 72.0*x[casfine] + 84.8*x[wheatbran] :   75.0 :   True
#             cp :  155.0 :            99.7*x[barley] + 800.0*x[blood] + 362.9*x[cotton] + 563.0*x[fish] + 384.0*x[fishlq] + 287.1*x[gnseeds] + 76.3*x[maize] + 90.6*x[maizebranhighq] + 94.3*x[maizebranlowq] + 455.5*x[mbmeal] + 34.8*x[sugars] + 438.7*x[soybeanexp] + 426.2*x[soybeanmeal] + 287.4*x[sunflower] + 176.0*x[sunflowerseeds] + 22.9*x[tapbran] + 34.0*x[caswhole] + 34.0*x[casfine] + 153.8*x[wheatbran] + 942.0*x[lysine] + 584.0*x[dl] + 840.0*x[ltryp] :  195.0 :   True
#          dargp :    7.0 :                                                                                                  3.9*x[barley] + 24.8*x[blood] + 32.7*x[cotton] + 30.6*x[fish] + 28.1*x[gnseeds] + 3.1*x[maize] + 3.9*x[maizebranhighq] + 4.0*x[maizebranlowq] + 27.6*x[mbmeal] - 0.2*x[sugars] + 28.9*x[soybeanexp] + 28.2*x[soybeanmeal] + 21.2*x[sunflower] + 12.8*x[sunflowerseeds] + 0.4*x[tapbran] + 0.6*x[caswhole] + 0.6*x[casfine] + 8.7*x[wheatbran] :   +Inf :   True
#          dlysp :    6.7 :                                                                                                                                        2.3*x[barley] + 51.3*x[blood] + 8.8*x[cotton] + 38.5*x[fish] + 7.5*x[gnseeds] + 1.4*x[maize] + 1.8*x[maizebranhighq] + 2.0*x[maizebranlowq] + 15.9*x[mbmeal] - 0.2*x[sugars] + 23.4*x[soybeanexp] + 22.7*x[soybeanmeal] + 7.9*x[sunflower] + 4.9*x[sunflowerseeds] + 4.5*x[wheatbran] + 788.0*x[lysine] :    7.9 :   True
#           dmcp :    5.1 :                                                                                                         2.9*x[barley] + 13.8*x[blood] + 8.1*x[cotton] + 18.8*x[fish] + 5.9*x[gnseeds] + 2.7*x[maize] + 3.1*x[maizebranhighq] + 3.1*x[maizebranlowq] + 6.3*x[mbmeal] + 10.4*x[soybeanexp] + 10.1*x[soybeanmeal] + 9.2*x[sunflower] + 5.9*x[sunflowerseeds] - 0.3*x[tapbran] - 0.4*x[caswhole] - 0.4*x[casfine] + 4.3*x[wheatbran] + 995.0*x[dl] :    6.1 :   True
#          dmetp :    2.8 :                                                                                                                                                                1.3*x[barley] + 6.9*x[blood] + 3.9*x[cotton] + 14.3*x[fish] + 2.8*x[gnseeds] + 1.4*x[maize] + 1.6*x[maizebranhighq] + 1.7*x[maizebranlowq] + 4.2*x[mbmeal] + 5.2*x[soybeanexp] + 5.0*x[soybeanmeal] + 5.5*x[sunflower] + 3.4*x[sunflowerseeds] + 1.8*x[wheatbran] + 995.0*x[dl] :   +Inf :   True
#          dthrp :    4.5 :                                                                                                                                                           2.3*x[barley] + 25.4*x[blood] + 8.0*x[cotton] + 20.1*x[fish] + 5.8*x[gnseeds] + 2.1*x[maize] + 2.4*x[maizebranhighq] + 2.4*x[maizebranlowq] + 9.4*x[mbmeal] - 0.1*x[sugars] + 14.2*x[soybeanexp] + 13.8*x[soybeanmeal] + 8.6*x[sunflower] + 5.1*x[sunflowerseeds] + 3.5*x[wheatbran] :   +Inf :   True
#          dtryp :    1.3 :                                                                                                                                                              0.9*x[barley] + 8.7*x[blood] + 3.2*x[cotton] + 5.6*x[fish] + 2.4*x[gnseeds] + 0.4*x[maize] + 0.5*x[maizebranhighq] + 0.5*x[maizebranlowq] + 1.7*x[mbmeal] + 4.9*x[soybeanexp] + 4.7*x[soybeanmeal] + 2.8*x[sunflower] + 1.8*x[sunflowerseeds] + 1.7*x[wheatbran] + 980.0*x[ltryp] :   +Inf :   True
#          dvalp :    5.4 :                                                                                                    3.6*x[barley] + 49.6*x[blood] + 11.8*x[cotton] + 32.3*x[fish] + 9.5*x[gnseeds] + 2.9*x[maize] + 3.8*x[maizebranhighq] + 3.8*x[maizebranlowq] + 12.5*x[mbmeal] + 0.1*x[sugars] + 17.8*x[soybeanexp] + 17.4*x[soybeanmeal] + 12.1*x[sunflower] + 7.2*x[sunflowerseeds] + 0.2*x[tapbran] + 0.3*x[caswhole] + 0.3*x[casfine] + 5.4*x[wheatbran] :   +Inf :   True
#             na :    1.4 :                                                                                                                               0.1*x[barley] + 5.8*x[blood] + 9.5*x[boneash] + 10.5*x[fish] + 10.5*x[fishlq] + 0.2*x[maizebranhighq] + 6.3*x[mbmeal] + 1.6*x[sugars] + 0.2*x[soybeanexp] + 0.2*x[soybeanmeal] + 0.2*x[sunflower] + 0.2*x[sunflowerseeds] + 0.1*x[tapbran] + 0.1*x[caswhole] + 0.1*x[casfine] + 0.2*x[wheatbran] + 380.0*x[salt] :    2.1 :   True
#           oebr : 2750.0 : 2656.5*x[barley] + 2450.0*x[blood] + 1730.0*x[cotton] + 2862.0*x[fish] + 5243.0*x[gnseeds] + 3227.8*x[maize] + 2893.4*x[maizebranhighq] + 1602.0*x[maizebranlowq] + 1820.0*x[mbmeal] + 2006.2*x[sugars] + 2474.0*x[soybeanexp] + 2012.7*x[soybeanmeal] + 1896.0*x[sunflower] + 4137.0*x[sunflowerseeds] + 2688.0*x[tapbran] + 2494.0*x[caswhole] + 2556.0*x[casfine] + 1558.3*x[wheatbran] + 3682.0*x[lysine] + 3669.0*x[dl] + 4026.0*x[ltryp] : 2850.0 :   True
#            opp :    3.5 :                                                                     1.2*x[barley] + 1.3*x[blood] + 82.9*x[boneash] + 3.1*x[cotton] + 19.6*x[fish] + 1.7*x[gnseeds] + 0.7*x[maize] + 1.4*x[maizebranhighq] + 1.7*x[maizebranlowq] + 38.1*x[mbmeal] + 0.4*x[sugars] + 2.5*x[soybeanexp] + 2.7*x[soybeanmeal] + 2.0*x[sunflower] + 1.6*x[sunflowerseeds] + 0.5*x[tapbran] + 0.5*x[caswhole] + 0.5*x[casfine] + 2.4*x[wheatbran] + 142.0*x[dicaph] :   +Inf :   True
#          staew :  300.0 :                                                                                                                                                                        539.3*x[barley] + 33.6*x[cotton] + 648.5*x[maize] + 489.3*x[maizebranhighq] + 310.8*x[maizebranlowq] + 8.0*x[soybeanexp] + 9.0*x[soybeanmeal] + 4.0*x[sunflower] + 5.0*x[sunflowerseeds] + 646.9*x[tapbran] + 581.0*x[caswhole] + 604.0*x[casfine] + 217.6*x[wheatbran] :   +Inf :   True
#     weight : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                   : Upper : Active
#         None :   1.0 : x[barley] + x[blood] + x[boneash] + x[cotton] + x[fish] + x[fishlq] + x[gnseeds] + x[maize] + x[maizebranhighq] + x[maizebranlowq] + x[mbmeal] + x[sugars] + x[soybeanexp] + x[soybeanmeal] + x[sunflower] + x[sunflowerseeds] + x[tapbran] + x[caswhole] + x[casfine] + x[wheatbran] + x[lysine] + x[dl] + x[ltryp] + x[dicaph] + x[shells] + x[salt] :   1.0 :   True
#
# 8 Declarations: ingredients nutrients cir x optimal weight nutrition combined
# CPU times: user 44.5 ms, sys: 18.8 ms, total: 63.3 ms
# Wall time: 120 ms
# ok optimal
# 0.2697643896412
# Model FeedCalculator
#
#   Variables:
#     x : Size=26, Index=ingredients
#         Key            : Lower : Value         : Upper : Fixed : Stale : Domain
#                 barley :     0 :           0.0 :   0.1 : False : False : NonNegativeReals
#                  blood :     0 :           0.0 :  0.03 : False : False : NonNegativeReals
#                boneash :     0 :           0.0 :  0.03 : False : False : NonNegativeReals
#                casfine :     0 :           0.0 :  0.25 : False : False : NonNegativeReals
#               caswhole :     0 :    0.18676756 :  0.25 : False : False : NonNegativeReals
#                 cotton :     0 :          0.05 :  0.06 : False : False : NonNegativeReals
#                 dicaph :     0 : 0.00052158349 :  None : False : False : NonNegativeReals
#                     dl :     0 : 0.00073393208 :  None : False : False : NonNegativeReals
#                   fish :     0 :   0.014126323 :  0.07 : False : False : NonNegativeReals
#                 fishlq :     0 :           0.0 :  0.07 : False : False : NonNegativeReals
#                gnseeds :     0 :   0.055750927 :   0.1 : False : False : NonNegativeReals
#                  ltryp :     0 :           0.0 :  None : False : False : NonNegativeReals
#                 lysine :     0 :  0.0015550651 :  None : False : False : NonNegativeReals
#                  maize :   0.2 :           0.2 :  None : False : False : NonNegativeReals
#         maizebranhighq :     0 :          0.25 :  0.25 : False : False : NonNegativeReals
#          maizebranlowq :     0 :           0.0 :  0.15 : False : False : NonNegativeReals
#                 mbmeal :     0 :          0.05 :  0.05 : False : False : NonNegativeReals
#                   salt :     0 :  0.0021850656 : 0.003 : False : False : NonNegativeReals
#                 shells :     0 :           0.0 :  None : False : False : NonNegativeReals
#             soybeanexp :     0 :   0.068359545 :  0.07 : False : False : NonNegativeReals
#            soybeanmeal :     0 :           0.0 :  0.32 : False : False : NonNegativeReals
#                 sugars :     0 :           0.0 :  0.01 : False : False : NonNegativeReals
#              sunflower :     0 :          0.12 :  0.12 : False : False : NonNegativeReals
#         sunflowerseeds :     0 :           0.0 :  0.12 : False : False : NonNegativeReals
#                tapbran :     0 :           0.0 :   0.2 : False : False : NonNegativeReals
#              wheatbran :     0 :           0.0 :  0.08 : False : False : NonNegativeReals
#
#   Objectives:
#     optimal : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 0.2697643896412
#
#   Constraints:
#     weight : Size=1
#         Key  : Lower : Body          : Upper
#         None :   1.0 : 1.00000000127 :   1.0
#     nutrition : Size=14
#         Key    : Lower  : Body               : Upper
#             ca :    7.0 :       9.0000000161 :    9.0
#         cfibre :    0.0 :      73.5109232771 :   75.0
#             cp :  155.0 :    175.51012808112 :  195.0
#          dargp :    7.0 :       11.240517919 :   None
#          dlysp :    6.7 :  6.700000039799999 :    7.9
#           dmcp :    5.1 :  5.100000005299999 :    6.1
#          dmetp :    2.8 : 3.1888410680999995 :   None
#          dthrp :    4.5 :  4.500000007900001 :   None
#          dtryp :    1.3 :       1.3338714041 :   None
#          dvalp :    5.4 :       6.4557442084 :   None
#             na :    1.4 :       1.3999999845 :    2.1
#           oebr : 2750.0 : 2750.0000021567207 : 2850.0
#            opp :    3.5 :      3.50000000478 :   None
#          staew :  300.0 :       363.24382872 :   None
#     combined : Size=7
#         Key : Lower : Body                : Upper
#           0 :  None : 0.16999999999999998 :  0.17
#           1 :  None :         0.068359545 :  0.35
#           2 :  None :                 0.0 :   0.3
#           3 :  None :                0.25 :  0.25
#           4 :  None :         0.014126323 :  0.07
#           5 :  None :                0.05 :  0.08
#           6 :  None :          0.18676756 :  0.25
